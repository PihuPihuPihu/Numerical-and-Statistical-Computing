# %%
# JACOBI ITERATIVE METHOD
import numpy as np
import pandas as pd
print("GIVEN QUESTION: Solve the system of equations using Jacobi Iterative Method.")
print("The system of equations is:\n")
print("10x + y + 2z = 27")
print("x + 10y + z = -11")
print("2x + y + 10z = 17")

# Step 1: Define the augmented matrix (Ax = b)
A = np.array([[10, 1, 2],  # Coefficients of the system
              [1, 10, 1],
              [2, 1, 10]], dtype=float)

b = np.array([27, -11, 17], dtype=float)  # Constants of the system

# Step 2: Jacobi Iterative method function
def jacobi(A, b, tol=1e-6, max_iter=100):
    n = len(A)
    x = np.zeros(n)  # Initial guess (x₀ = 0)
    
    print("Iteration\t xₙ₋₁ \t\t xₙ \t\t Error")

    for i in range(max_iter):
        x_new = np.zeros(n)
        
        # Perform the Jacobi iteration
        for j in range(n):
            sum_ = np.dot(A[j, :], x) - A[j, j] * x[j]  # Sum excluding the diagonal element
            x_new[j] = (b[j] - sum_) / A[j, j]  # Update x[j]
        
        # Calculate the error (difference between old and new solution)
        error = np.linalg.norm(x_new - x, ord=np.inf)
        
        print(f"{i+1}\t\t {x}\t {x_new}\t {error:.6f}")

        if error < tol:
            print(f"\nSolution converged after {i+1} iterations")
            print(f"Final solution: x = {x_new}")
            return x_new
        
        x = x_new  # Update solution

    print("\nMax iterations reached. Approximate solution:", x_new)
    return x_new

# Step 3: Call the function with initial guess x₀ = 0
jacobi(A, b)
# Out:
# GIVEN QUESTION: Solve the system of equations using Jacobi Iterative Method.
# The system of equations is:
#
# 10x + y + 2z = 27
# x + 10y + z = -11
# 2x + y + 10z = 17
# Iteration	 xₙ₋₁ 		 xₙ 		 Error
# 1		 [0. 0. 0.]	 [ 2.7 -1.1  1.7]	 2.700000
# 2		 [ 2.7 -1.1  1.7]	 [ 2.47 -1.54  1.27]	 0.440000
# 3		 [ 2.47 -1.54  1.27]	 [ 2.6   -1.474  1.36 ]	 0.130000
# 4		 [ 2.6   -1.474  1.36 ]	 [ 2.5754 -1.496   1.3274]	 0.032600
# 5		 [ 2.5754 -1.496   1.3274]	 [ 2.58412 -1.49028  1.33452]	 0.008720
# 6		 [ 2.58412 -1.49028  1.33452]	 [ 2.582124 -1.491864  1.332204]	 0.002316
# 7		 [ 2.582124 -1.491864  1.332204]	 [ 2.5827456 -1.4914328  1.3327616]	 0.000622
# 8		 [ 2.5827456 -1.4914328  1.3327616]	 [ 2.58259096 -1.49155072  1.33259416]	 0.000167
# 9		 [ 2.58259096 -1.49155072  1.33259416]	 [ 2.58263624 -1.49151851  1.33263688]	 0.000045
# 10		 [ 2.58263624 -1.49151851  1.33263688]	 [ 2.58262448 -1.49152731  1.3326246 ]	 0.000012
# 11		 [ 2.58262448 -1.49152731  1.3326246 ]	 [ 2.58262781 -1.49152491  1.33262784]	 0.000003
# 12		 [ 2.58262781 -1.49152491  1.33262784]	 [ 2.58262692 -1.49152556  1.33262693]	 0.000001
#
# Solution converged after 12 iterations
# Final solution: x = [ 2.58262692 -1.49152556  1.33262693]
# array([ 2.58262692, -1.49152556,  1.33262693])
